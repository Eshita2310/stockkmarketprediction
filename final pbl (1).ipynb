# %%
import pandas as pd
from datetime import datetime
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from matplotlib.pyplot import figure

# %% [markdown]
#  Reading data of NIFTY 50 INDEX:

# %%
df = pd.read_csv(r"C:\Users\rajku\OneDrive\Desktop\PBL 2\^NSEI (1).csv")

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2017-01-02  8210.099609  8212.000000  8133.799805  8179.500000
# 1  2017-01-03  8196.049805  8219.099609  8148.600098  8192.250000
# 2  2017-01-04  8202.650391  8218.500000  8180.899902  8190.500000
# 3  2017-01-05  8226.650391  8282.650391  8223.700195  8273.799805
# 4  2017-01-06  8281.849609  8306.849609  8233.250000  8243.799805
#
#      Adj Close    Volume
# 0  8179.500000  118300.0
# 1  8192.250000  127300.0
# 2  8190.500000  132400.0
# 3  8273.799805  159100.0
# 4  8243.799805  139400.0

# %%
df.tail()
# Out:
#             Date          Open          High           Low         Close  \
# 1397  2022-08-26  17619.300781  17685.849609  17519.349609  17558.900391
# 1398  2022-08-29  17188.650391  17380.150391  17166.199219  17312.900391
# 1399  2022-08-30  17414.949219  17777.650391  17401.500000  17759.300781
# 1400  2022-09-01  17485.699219  17695.599609  17468.449219  17542.800781
# 1401  2022-09-02  17598.400391  17643.849609  17476.449219  17539.449219
#
#          Adj Close    Volume
# 1397  17558.900391  266600.0
# 1398  17312.900391  244900.0
# 1399  17759.300781  324700.0
# 1400  17542.800781  308500.0
# 1401  17539.449219  256300.0

# %%
print("Shape of the dataframe is : ",df.shape)
# Out:
# Shape of the dataframe is :  (1402, 7)

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   1398.000000   1398.000000   1398.000000   1398.000000   1398.000000
# mean   12411.282124  12472.527647  12326.155457  12401.688521  12401.688521
# std     2811.365608   2824.549529   2792.280074   2811.038470   2811.038470
# min     7735.149902   8036.950195   7511.100098   7610.250000   7610.250000
# 25%    10405.550048  10455.175049  10342.500244  10418.212891  10418.212891
# 50%    11380.049805  11426.900391  11303.225098  11357.975097  11357.975097
# 75%    14887.112305  14964.950195  14764.324951  14895.462891  14895.462891
# max    18602.349609  18604.449219  18445.300781  18477.050781  18477.050781
#
#              Volume
# count  1.398000e+03
# mean   3.879740e+05
# std    2.237471e+05
# min    0.000000e+00
# 25%    2.264000e+05
# 50%    3.146000e+05
# 75%    5.226750e+05
# max    1.811000e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1402 entries, 0 to 1401
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1402 non-null   object
#  1   Open       1398 non-null   float64
#  2   High       1398 non-null   float64
#  3   Low        1398 non-null   float64
#  4   Close      1398 non-null   float64
#  5   Adj Close  1398 non-null   float64
#  6   Volume     1398 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 76.8+ KB

# %% [markdown]
# # Plotting daily highs and lows of NIFTY 50 INDEX over the last 5 years:

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(15,8))
fig = sns.lineplot(data=df,x= "Date", y = "High",color='mediumspringgreen')
fig = sns.lineplot(data=df,x= "Date", y = "Low",color='crimson')
fig.set(title='NIFTY50 High')
fig.text(748, 14000,'Covid Outbreak', fontsize=15)

fig.axvline(780, 0,2,color='r')
fig.set_xticks([1,248,496,744,992,1240])

fig.set_xticklabels(['2017', '2018', '2019', '2020', '2021', '2022'])
# Out:
# [Text(1, 0, '2017'),
#  Text(248, 0, '2018'),
#  Text(496, 0, '2019'),
#  Text(744, 0, '2020'),
#  Text(992, 0, '2021'),
#  Text(1240, 0, '2022')]

# %% [markdown]
# Conclusions: Linear, steady growth observed. Sharp dip during March 2020 (Covid outbreak)

# %%
df["Date"]
# Out:
# 0       2017-01-02
# 1       2017-01-03
# 2       2017-01-04
# 3       2017-01-05
# 4       2017-01-06
#            ...
# 1397    2022-08-26
# 1398    2022-08-29
# 1399    2022-08-30
# 1400    2022-09-01
# 1401    2022-09-02
# Name: Date, Length: 1402, dtype: object

# %%
datetime_series = pd.Series(pd.date_range("2000-01-01", periods=3, freq="M"))
datetime_series.dt.month
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
df["Date_dt"] = df["Date"].values.astype('datetime64[D]')

# %%
df["Month"] = df["Date_dt"].dt.month

# %%
df["Week"] = df["Date_dt"].dt.week

# %%
df["Day"] = df["Date_dt"].dt.day

# %%
df["Year"] = df["Date_dt"].dt.year

# %%
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2017-01-02  8210.099609  8212.000000  8133.799805  8179.500000
# 1  2017-01-03  8196.049805  8219.099609  8148.600098  8192.250000
# 2  2017-01-04  8202.650391  8218.500000  8180.899902  8190.500000
# 3  2017-01-05  8226.650391  8282.650391  8223.700195  8273.799805
# 4  2017-01-06  8281.849609  8306.849609  8233.250000  8243.799805
#
#      Adj Close    Volume    Date_dt  Month  Week  Day  Year
# 0  8179.500000  118300.0 2017-01-02      1     1    2  2017
# 1  8192.250000  127300.0 2017-01-03      1     1    3  2017
# 2  8190.500000  132400.0 2017-01-04      1     1    4  2017
# 3  8273.799805  159100.0 2017-01-05      1     1    5  2017
# 4  8243.799805  139400.0 2017-01-06      1     1    6  2017

# %% [markdown]
# # Histogram to plot occurences of daily high of NIFTY 50(Year-wise):

# %%
plt.figure(figsize=(15,8))
fig = sns.histplot(data=df,x="High",hue='Year')

# %% [markdown]
# Conclusion:In the year 2018 the market was very rigid, most repeated value of the daily highs was between 10,500 and 11,000

# %% [markdown]
# # Correlational heatmap between NIFTY50 features

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(),cmap="YlGnBu",annot=True,ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Plotting Average high of NIFTY 50 index over the last 5 years:

# %%
df.groupby(["Year"])["High"].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# Conclusions: 2022 has the highest notable average high

# %% [markdown]
# # Box plot of yearly high's of NIFTY 50 in the last 5 years:

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(9,5))
ax = sns.boxplot(x="Year",y="High",data=df)

# %% [markdown]
# # Plotting the volume of NIFTY 50 stock traded in the last 5 years(daily):

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(15,8))
fig = sns.lineplot(data=df,x= "Date", y = "Volume",color='mediumspringgreen',linewidth=1.5)
fig.set(title='NIFTY50 High')
fig.axvline(780, 0,2,color='r')
fig.text(790, 1650000,'Covid Outbreak', fontsize=15)
fig.set_xticks([1,248,496,744,992,1240])

fig.set_xticklabels(['2017', '2018', '2019', '2020', '2021', '2022'])
# Out:
# [Text(1, 0, '2017'),
#  Text(248, 0, '2018'),
#  Text(496, 0, '2019'),
#  Text(744, 0, '2020'),
#  Text(992, 0, '2021'),
#  Text(1240, 0, '2022')]

# %% [markdown]
# Conclusion: The volume of stock traded was highest right after the covid outbreak

# %%
df2 = pd.read_csv(r"C:\Users\rajku\OneDrive\Desktop\PBL 2\50-stocks.csv")

# %% [markdown]
# Loading 50 stocks of NIFTY50 with their daily prices:

# %%
df2.head()
# Out:
#          DATE  TATASTEEL   WIPRO    TITAN  ULTRACEMO   TECHM  RELIANCE  \
# 0  2010-01-11     591.90  423.70  3792.50    6737.95  735.60   1093.20
# 1  2010-01-12     613.55  414.70  3781.90    5443.70  671.15    988.80
# 2  2010-02-11     599.05  433.85  3818.70    6735.25  724.55   1074.85
# 3  2010-02-12     622.75  426.05  3784.20    5368.40  676.35   1011.15
# 4  2010-03-11     609.60  434.70  3833.05    6858.65  732.50   1065.30
#
#    SHREECEM  SUNPHARMA  TATAMOTORS      TCS     SBIN  NESTLEIND    NTPC  \
# 0   2116.10    2190.70     1170.60  1053.40  3198.45    3550.40  193.20
# 1   2094.10     448.65     1286.75  1081.90  3100.15    3568.05  186.35
# 2   2164.55    2190.45     1154.25  1049.45  3201.85    3552.60  193.75
# 3   2022.35     452.90     1320.15  1095.80  3099.20    3646.20  182.90
# 4   2261.40    2249.30     1185.55  1052.80  3272.60    3609.95  193.20
#
#       M&M   MARUTI     ONGC  POWERGRID  JSWSTEEL  KOTAKBANK       LT  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2711 entries, 0 to 2710
# Data columns (total 47 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DATE          2711 non-null   object
#  1   TATASTEEL     2711 non-null   float64
#  2   WIPRO         2711 non-null   float64
#  3   TITAN         2711 non-null   float64
#  4   ULTRACEMO     2711 non-null   float64
#  5   TECHM         2711 non-null   float64
#  6   RELIANCE      2711 non-null   float64
#  7   SHREECEM      2711 non-null   float64
#  8   SUNPHARMA     2711 non-null   float64
#  9   TATAMOTORS    2711 non-null   float64
#  10  TCS           2711 non-null   float64
#  11  SBIN          2711 non-null   float64
#  12  NESTLEIND     2711 non-null   float64
#  13  NTPC          2711 non-null   float64
#  14  M&M           2711 non-null   float64
#  15  MARUTI        2711 non-null   float64
#  16  ONGC          2711 non-null   float64
# ...

# %%
df2["Date_dt"] = df2["DATE"].values.astype('datetime64[D]')

# %%
df2["Year"] = df2["Date_dt"].dt.year

# %%
df2["Year"].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        2021], dtype=int64)

# %%
df_new = df2.loc[df2["Year"] > 2016,:]

# %% [markdown]
# Keeping data of only the past 5 years:

# %%
df_new = df_new.reset_index()

# %%
df_new.drop("index",axis='columns',inplace=True)

# %%
df_new.head()
# Out:
#          DATE  TATASTEEL   WIPRO   TITAN  ULTRACEMO   TECHM  RELIANCE  \
# 0  2017-01-02     474.60  456.00  369.95    4079.95  449.70   1049.65
# 1  2017-01-03     500.35  488.55  438.15    3570.55  499.75   1234.50
# 2  2017-01-06     497.15  541.15  470.70    4177.80  397.70   1328.25
# 3  2017-01-08     572.40  294.80  539.35    3918.20  402.45   1603.60
# 4  2017-01-09     651.20  296.45  613.50    4179.45  423.40   1610.10
#
#    SHREECEM  SUNPHARMA  TATAMOTORS      TCS    SBIN  NESTLEIND    NTPC  \
# 0  15937.65     625.55      542.25  2167.90  270.70    5912.45  170.90
# 1  16126.30     694.65      449.45  2479.55  271.75    6250.40  159.95
# 2  17666.75     507.45      476.65  2553.60  287.45    6605.85  160.65
# 3  18631.70     533.80      446.90  2501.65  309.00    6703.00  165.20
# 4  17795.40     486.20      390.85  2456.45  277.85    7015.30  168.25
#
#        M&M  MARUTI    ONGC  POWERGRID  JSWSTEEL  KOTAKBANK       LT  \
# ...

# %%
print("Shape of the dataframe is : ",df_new.shape)
# Out:
# Shape of the dataframe is :  (1172, 49)

# %%
df_new.describe()
# Out:
#         TATASTEEL        WIPRO        TITAN    ULTRACEMO        TECHM  \
# count  1172.00000  1172.000000  1172.000000  1172.000000  1172.000000
# mean    587.95192   339.164292  1044.864377  3099.191724   716.443729
# std     252.85155   113.403487   380.807584  1679.124141   227.140123
# min     253.75000   162.350000   333.950000   897.250000   376.300000
# 25%     441.06250   262.512500   826.062500  1844.737500   535.812500
# 50%     523.47500   293.850000   989.575000  2864.400000   701.550000
# 75%     651.22500   385.725000  1249.437500  3982.550000   804.762500
# max    1519.40000   708.250000  2564.050000  8026.250000  1521.500000
#
#           RELIANCE      SHREECEM    SUNPHARMA   TATAMOTORS          TCS  \
# count  1172.000000   1172.000000  1172.000000  1172.000000  1172.000000
# mean   1451.037500  20141.028626   534.027816   263.816041  2468.935708
# std     442.318763   4049.469570   101.427087   124.753104   509.553279
# ...

# %%
finance_stocks = ['HDFCBANK','HDFC','SBIN','KOTAKBANK','ICICIBANK','BAJAJFINSERV','INDUSBANK','BAJAJFINANCE']
it_stocks = ['TCS','INFY','WIPRO','TECHM','HCLTECH']
energy_stocks = ['IOC','NTPC','ONGC','POWERGRID','BPCL','COALINDIA']
pharma_stocks = ['SUNPHARMA','DRREDDYS','CIPLA']
automobile_stocks = ['TATAMOTORS','MARUTI','HEROMOTOCO','EICHERMOTOR']

# %%
df_sector = pd.DataFrame()
df_sector["NIFTY_Finance"] = df_new[finance_stocks].sum(axis=1)
df_sector["NIFTY_IT"] = df_new[it_stocks].sum(axis=1)
df_sector["NIFTY_Energy"] = df_new[energy_stocks].sum(axis=1)
df_sector["NIFTY_Pharma"] = df_new[pharma_stocks].sum(axis=1)
df_sector["NIFTY_Automobile"] = df_new[automobile_stocks].sum(axis=1)

# %%
df_sector.head()
# Out:
#    NIFTY_Finance  NIFTY_IT  NIFTY_Energy  NIFTY_Pharma  NIFTY_Automobile
# 0        9748.85   4804.30       1951.70       4198.90          34038.05
# 1       10493.10   5342.10       1899.75       4204.25          33256.90
# 2       11801.10   5326.10       1942.30       3545.80          40150.00
# 3       13652.40   5088.65       1635.85       3527.80          43535.65
# 4       14083.35   4962.00       1745.45       3272.15          44024.50

# %% [markdown]
# # Finance sector:

# %%
plt.figure(figsize=(15,6))
sns.set_style('whitegrid')
plt.title('Finance portfolio in the last 5 years')
sns.lineplot(df_new.Year,df_new.HDFCBANK,label='HDFCBANK',color='blue').set(xlabel='Years',ylabel='stock Price');
sns.lineplot(df_new.Year,df_new.HDFC,label='HDFC',color='purple').set(xlabel='Years',ylabel='stock Price');
sns.lineplot(df_new.Year,df_new.SBIN,label="SBI",color='yellow').set(xlabel='Years',ylabel='stock Price');
sns.lineplot(df_new.Year,df_new.KOTAKBANK,label='KOTAK MAHINDRA',color='green').set(xlabel='Years',ylabel='stock Price');
sns.lineplot(df_new.Year,df_new.ICICIBANK,label='ICICI',color='red').set(xlabel='Years',ylabel='stock Price');
sns.lineplot(df_new.Year,df_new.AXISBANK,label='AXISBANK',color='gray').set(xlabel='Years',ylabel='stock Price');
sns.lineplot(df_new.Year,df_new.BAJAJFINSERV,label='BAJAJFINSERV',color='black').set(xlabel='Years',ylabel='stock Price');
sns.lineplot(df_new.Year,df_new.INDUSBANK,label='INDUSBANK',color='cyan').set(xlabel='Years',ylabel='stock Price');
sns.lineplot(df_new.Year,df_new.BAJAJFINANCE,label='BAJAJFINANCE',color='pink').set(xlabel='Years',ylabel='stock Price');

# %% [markdown]
# Conclusions: Bajaj Finserv has shown a huge growth in stock price over the last 5 years

# %% [markdown]
# # IT sector:

# %%
plt.figure(figsize=(15,6))
sns.set_style('whitegrid')
plt.title('IT stocks in the last 5 Years')
sns.lineplot(df_new.Year,df_new.TCS,label='TCS',color='aqua').set(xlabel='Years',ylabel='stock Price');
sns.lineplot(df_new.Year,df_new.INFY,label='INFOSYS',color='mediumspringgreen').set(xlabel='Years',ylabel='Stock Price');
sns.lineplot(df_new.Year,df_new.WIPRO,label='WIPRO',color='hotpink').set(xlabel='Years',ylabel='Stock price');
sns.lineplot(df_new.Year,df_new.TECHM,label='TECH MAHINDRA',color='crimson').set(xlabel='Years',ylabel='Stock Price');
sns.lineplot(df_new.Year,df_new.HCLTECH,label='HCLTECH',color='chocolate').set(xlabel='Years',ylabel=' stock Price');

# %% [markdown]
# Conclusion: Post-Covid TCS has seen maximum growth in this portfolio

# %% [markdown]
# # Oil and energy sector:

# %%
plt.figure(figsize=(15,6))
sns.set_style('whitegrid')
plt.title('OIL and ENERGY stocks in the last 5 Years')
sns.lineplot(df_new.Year,df_new.IOC,label='INDIAN OIL COORPORATION',color='black').set(xlabel='Years',ylabel='Stock Price');
sns.lineplot(df_new.Year,df_new.NTPC,label='NTPC',color='darkorange').set(xlabel='Years',ylabel='stock Price');
sns.lineplot(df_new.Year,df_new.ONGC,label='ONGC',color='lime').set(xlabel='Years',ylabel='Stock Price');
sns.lineplot(df_new.Year,df_new.POWERGRID,label='POWERGRID',color='royalblue').set(xlabel='Years',ylabel='Stock price');
sns.lineplot(df_new.Year,df_new.BPCL,label='BPCL',color='crimson').set(xlabel='Years',ylabel='Stock Price');
sns.lineplot(df_new.Year,df_new.COALINDIA,label='COAL INDIA',color='m').set(xlabel='Years',ylabel=' stock Price');

# %% [markdown]
# Conclusions: This portfolio has had no notable growth in the last 5 years

# %% [markdown]
# # Pharma sector:

# %%
plt.figure(figsize=(15,6))
sns.set_style('whitegrid');
plt.title('Pharma stocks in the last 5 years');
sns.lineplot(df_new.Year,df_new.SUNPHARMA,color='darkgoldenrod',label='sunpharma').set(xlabel="Years",ylabel='Stock price');
sns.lineplot(df_new.Year,df_new.DRREDDYS,color='chartreuse',label="DR Reddy's").set(xlabel='Years',ylabel='Stock price');
sns.lineplot(df_new.Year,df_new.CIPLA,color='cadetblue',label='CIPLA').set(xlabel='Years',ylabel='Stock price');

# %% [markdown]
# Conclusions: Dr Reddy's has had maximum growth in the last 5 years

# %% [markdown]
# # Automobile sector:

# %%
plt.figure(figsize=(15,6))
sns.set_style('whitegrid');
plt.title('Automobile stocks in the last 5 years');
sns.lineplot(df_new.Year,df_new.TATAMOTORS,color='darkgray',label='TATA MOTORS').set(xlabel="Years",ylabel='Stock price');
sns.lineplot(df_new.Year,df_new.MARUTI,color='tomato',label="MARUTI").set(xlabel='Years',ylabel='Stock price');
sns.lineplot(df_new.Year,df_new.HEROMOTOCO,color='cadetblue',label='HEROMOTOCO').set(xlabel='Years',ylabel='Stock price');
sns.lineplot(df_new.Year,df_new.EICHERMOTOR,color='darkviolet',label='EICHERMOTOR').set(xlabel='Years',ylabel='Stock price');

# %% [markdown]
# Conclusions: Eicher Motor has seen the maximum decline in stock price

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(15,10))
ax = sns.boxplot(data=df_sector)

# %%
df_sector["Year"] = df_new["Year"]

# %%
df_sector["Date"] = df_new["DATE"]

# %%
df_sector.head()
# Out:
#    NIFTY_Finance  NIFTY_IT  NIFTY_Energy  NIFTY_Pharma  NIFTY_Automobile  \
# 0        9748.85   4804.30       1951.70       4198.90          34038.05
# 1       10493.10   5342.10       1899.75       4204.25          33256.90
# 2       11801.10   5326.10       1942.30       3545.80          40150.00
# 3       13652.40   5088.65       1635.85       3527.80          43535.65
# 4       14083.35   4962.00       1745.45       3272.15          44024.50
#
#    Year        Date
# 0  2017  2017-01-02
# 1  2017  2017-01-03
# 2  2017  2017-01-06
# 3  2017  2017-01-08
# 4  2017  2017-01-09

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
sns.lineplot(ax=axes[0, 0], data=df_sector, x='Year', y='NIFTY_Finance',color='cadetblue')
sns.lineplot(ax=axes[0, 1], data=df_sector, x='Year', y='NIFTY_IT',color='darkgoldenrod')
sns.lineplot(ax=axes[0, 2], data=df_sector, x='Year', y='NIFTY_Energy',color='darkviolet')
sns.lineplot(ax=axes[1, 0], data=df_sector, x='Year', y='NIFTY_Pharma',color='crimson')
sns.lineplot(ax=axes[1, 1], data=df_sector, x='Year', y='NIFTY_Automobile',color='aqua')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='NIFTY_Automobile'>

# %% [markdown]
# Conclusion:
# Energy and automobile sectors have taken a big hit
# Steady growth for Finance,Pharma and IT

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_sector.corr(),cmap="YlGnBu",annot=True,ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Conclusion:

# %% [raw]
# Strong -ve corr between Automobiles and Year
# Strong -ve corr between Energy and Year
# Strong +ve corr between Automobiles and Energy
# Strong +ve corr between Finance and Year
# Strong +ve corr between Pharma and Year
# Healthy corr between Finance and IT

# %% [markdown]
# # Pre-processing and normalization

# %%
df.ffill(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Date_dt      0
# Month        0
# Week         0
# Day          0
# Year         0
# dtype: int64

# %%
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2017-01-02  8210.099609  8212.000000  8133.799805  8179.500000
# 1  2017-01-03  8196.049805  8219.099609  8148.600098  8192.250000
# 2  2017-01-04  8202.650391  8218.500000  8180.899902  8190.500000
# 3  2017-01-05  8226.650391  8282.650391  8223.700195  8273.799805
# 4  2017-01-06  8281.849609  8306.849609  8233.250000  8243.799805
#
#      Adj Close    Volume    Date_dt  Month  Week  Day  Year
# 0  8179.500000  118300.0 2017-01-02      1     1    2  2017
# 1  8192.250000  127300.0 2017-01-03      1     1    3  2017
# 2  8190.500000  132400.0 2017-01-04      1     1    4  2017
# 3  8273.799805  159100.0 2017-01-05      1     1    5  2017
# 4  8243.799805  139400.0 2017-01-06      1     1    6  2017

# %%
df_close = df.reset_index()['Close']

# %%
df_close.isnull().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))  #Create an instance of the MinMaxScaler class, with the feature range set to be between 0 and 
df_close = scaler.fit_transform(np.array(df_close).reshape(-1,1))

# %%
df_close[:10]
# Out:
# array([[0.05238432],
#        [0.05355762],
#        [0.05339658],
#        [0.06106211],
#        [0.05830141],
#        [0.05758823],
#        [0.06242404],
#        [0.07089487],
#        [0.07333807],
#        [0.07270766]])

# %%
train_size = int(len(df_close)*0.75)
test_size = (len(df_close)*0.25)

# %%
train_size,test_size
# Out:
# (1051, 350.5)

# %%
df_train = df_close[0:train_size,:]
df_test = df_close[train_size:len(df_close),:1]

# %%
df_train.shape
# Out:
# (1051, 1)

# %%
df_test
# Out:
# array([[0.65090454],
#        [0.6633783 ],
#        [0.66841658],
#        [0.66483225],
#        [0.6166074 ],
#        [0.63445994],
#        [0.64151357],
#        [0.64486317],
#        [0.62108438],
#        [0.61528232],
#        [0.62538189],
#        [0.6194187 ],
#        [0.6326379 ],
#        [0.64810241],
#        [0.66756536],
#        [0.67035833],
#        [0.64608248],
#        [0.64636322],
#        [0.63369617],
#        [0.64486317],
#        [0.65470509],
#        [0.66375565],
#        [0.67472477],
#        [0.66629546],
#        [0.65210085],
#        [0.65037999],
#        [0.67295799],
#        [0.68997764],
#        [0.68280449],
#        [0.67138433],
#        [0.69616164],
#        [0.698223  ],
#        [0.69921225],
#        [0.70777042],
#        [0.71112002],
#        [0.72011998],
#        [0.73366117],
#        [0.73292957],
#        [0.73305385],
#        [0.74355827],
#        [0.74170864],
#        [0.74919938],
#        [0.74813644],
# ...

# %%
sns.lineplot(data=df_close,color='aqua')
# Out:
# <AxesSubplot:>

# %%
#  creating  Python function that creates input-output pairs for a time series prediction problem.
# X contains sequences of 80 consecutive values from the time series. Each sequence is obtained by taking a slice of the input dataset starting from the i-th index and ending at the i+80-th index.
# Y contains the output values corresponding to each input sequence in X. Each output value is the 81st value in the time series after the corresponding input sequence.

def create_time_data(dataset):
    X = []
    Y = []
    for i in range(len(dataset)-81):
        a = dataset[i:(i+80),0]
        X.append(a)
        Y.append(dataset[i + 80,0])
    return np.array(X), np.array(Y)

# %%
X_train,Y_train = create_time_data(df_train)

# %%
X_test,Y_test = create_time_data(df_test)

# %%
X_train.shape
# Out:
# (970, 80)

# %% [markdown]
# Reshaping X_train and X_test for LSTM model :

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)  #  Reshaping X_train and X_test for LSTM model

# %%
X_train.shape
# Out:
# (970, 80, 1)

# %%
Y_train.shape
# Out:
# (970,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.layers import LSTM

# %%
model=Sequential() #create a new sequential model object
model.add(LSTM(50,return_sequences=True,input_shape=(80,1))) # # add a LSTM layer with 50 units 
model.add(LSTM(50,return_sequences=True)) ## add another LSTM layer with 50 units and return sequences
model.add(LSTM(50)) #add a third LSTM layer with 50 units and do not return sequences
model.add(Dense(1)) # add a dense layer with 1 output unit
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 80, 50)            10400
#
#  lstm_1 (LSTM)               (None, 80, 50)            20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
history1 = model.fit(X_train,Y_train,validation_data=(X_test,Y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 31s 636ms/step - loss: 0.0262 - val_loss: 0.1199
# Epoch 2/100
# 16/16 [==============================] - 5s 308ms/step - loss: 0.0044 - val_loss: 0.0491
# Epoch 3/100
# 16/16 [==============================] - 5s 321ms/step - loss: 0.0025 - val_loss: 0.0113
# Epoch 4/100
# 16/16 [==============================] - 5s 309ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 5/100
# 16/16 [==============================] - 5s 323ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 6/100
# 16/16 [==============================] - 4s 266ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 7/100
# 16/16 [==============================] - 4s 244ms/step - loss: 0.0012 - val_loss: 0.0045
# Epoch 8/100
# 16/16 [==============================] - 5s 305ms/step - loss: 0.0011 - val_loss: 0.0026
# Epoch 9/100
# 16/16 [==============================] - 4s 263ms/step - loss: 0.0010 - val_loss: 0.0023
# Epoch 10/100
# ...

# %%
plt.plot(history1.history['loss'], label='Training loss')
plt.plot(history1.history['val_loss'], label='Validation loss')
plt.legend()

# %%
history1.history["val_loss"][-1]
# Out:
# 0.0011251323157921433

# %%
plt.plot(history1.history['loss'][10:100], label='Training loss')
plt.plot(history1.history['val_loss'][10:100], label='Validation loss')
plt.legend()

# %% [markdown]
# Hyperparameter tuning:

# %% [markdown]
# 1) Finding optimal number of epochs.

# %%
loss_list = []

# %%
for i in range(1,4):  ## loop over 3 different numbers of epochs
  hist = model.fit(X_train,Y_train,validation_data=(X_test,Y_test),epochs=i*50,batch_size=64,verbose=1)
  plt.plot(hist.history['loss'], color='blue')
  plt.plot(hist.history['val_loss'], color='orange')
  plt.show()
  loss_list.append(hist.history["val_loss"][-1])
# Out:
# Epoch 1/50
# 16/16 [==============================] - 5s 308ms/step - loss: 2.2347e-04 - val_loss: 0.0033
# Epoch 2/50
# 16/16 [==============================] - 5s 291ms/step - loss: 2.1064e-04 - val_loss: 0.0018
# Epoch 3/50
# 16/16 [==============================] - 4s 242ms/step - loss: 2.0330e-04 - val_loss: 0.0015
# Epoch 4/50
# 16/16 [==============================] - 5s 300ms/step - loss: 2.0581e-04 - val_loss: 0.0015
# Epoch 5/50
# 16/16 [==============================] - 3s 221ms/step - loss: 2.1658e-04 - val_loss: 4.9967e-04
# Epoch 6/50
# 16/16 [==============================] - 4s 264ms/step - loss: 2.6797e-04 - val_loss: 4.4449e-04
# Epoch 7/50
# 16/16 [==============================] - 5s 309ms/step - loss: 2.3142e-04 - val_loss: 5.1244e-04
# Epoch 8/50
# 16/16 [==============================] - 5s 312ms/step - loss: 2.0392e-04 - val_loss: 0.0013
# Epoch 9/50
# 16/16 [==============================] - 5s 306ms/step - loss: 1.9343e-04 - val_loss: 0.0023
# Epoch 10/50
# ...

# %% [markdown]
# 2) Finding number of hidden layers and parameters:

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV

# %%
import tensorflow as tf

# %%
from keras.layers import Dense, Activation, Embedding, Flatten, LeakyReLU, BatchNormalization, Dropout
from keras.activations import relu, sigmoid

# %%
def create_model(layers, activation):
    model = Sequential() ## create a new Sequential model
    for i, nodes in enumerate(layers): # loop over the number of layers and the number of nodes in each layer
        if i==0:      # For first layer
            model.add(LSTM(nodes,return_sequences=True,input_shape=(80,1))) ## add an LSTM layer with the specified number of nodes, taking input of shape (80,1)
            model.add(Activation(activation))
        else:
            model.add(LSTM(nodes,return_sequences=True)) # add a subsequent LSTM layer with the specified number of nodes
            model.add(Activation(activation))
    model.add(Dense(1))

    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
model = KerasClassifier(build_fn=create_model, verbose=0)

# %%
layers = [[20], [50, 20], [50, 50, 50]]
activations = ['sigmoid', 'relu']
param_grid = dict(layers=layers,activation=activations,batch_size = [64,128], epochs=[100])
grid = GridSearchCV(estimator=model, param_grid=param_grid,cv=2)

# %%
grid_result = grid.fit(X_train, Y_train)

# %%
grid_result.best_params_

# %%
grid_df = pd.DataFrame(grid.cv_results_)

# %%
grid_df[['param_layers','rank_test_score','params']]

# %% [markdown]
# Creating a new LSTM based on best parameters,(results from grid were not in the right dim)

# %%
fin_model=Sequential()
fin_model.add(LSTM(20,return_sequences=True,input_shape=(80,1)))
fin_model.add(LSTM(20))
fin_model.add(Dense(1))
fin_model.compile(loss='mean_squared_error',optimizer='adam')

# %%
fin_model.summary()

# %%
history_fin = fin_model.fit(X_train,Y_train,validation_data=(X_test,Y_test),epochs=100,batch_size=64,verbose=1)

# %%
train_pred = fin_model.predict(X_train)
test_pred = fin_model.predict(X_test)

# %%
train_pred.shape

# %%
train_pred=scaler.inverse_transform(train_pred)
test_pred=scaler.inverse_transform(test_pred)

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(Y_train,train_pred))    # RMSE on train set

# %%
math.sqrt(mean_squared_error(Y_test,test_pred))     # RMSE on test set

# %%
# RMSE of final model : 16825.882943532062

# %%
test_pred.shape

# %%
len(df_close)-1

# %%
look_back=100  ## Set the number of past time steps to use as input for the model
trainPredictPlot = np.empty_like(df_close)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_pred)+look_back, :] = train_pred
# shift test predictions for plotting
testPredictPlot = np.empty_like(df_close)
testPredictPlot[:, :] = np.nan
testPredictPlot[1131:1401, :] = test_pred
# testPredictPlot[270, :] = test_pred
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df_close))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
def make_preds(input_df):                           # Function to accept dataframe of a single feature(Closing price) with the closing
# prices for the last 80 days.
  scaler = MinMaxScaler(feature_range=(0,1))
  input_df = input_df.iloc[::-1]    # inverting dataframe
  input_df = scaler.fit_transform(np.array(input_df).reshape(-1,1))
  X,Y = create_time_data(input_df)                  # Converting into X numpy array with 80 features and a Y numpy array.
  print(X.shape)
  X = X.reshape(X.shape[0],X.shape[1] , 1)          # Reshaping array for LSTM model
  X = X[-1:]
  fin_pred = model_test.predict(X)
  fin_pred = scaler.inverse_transform(fin_pred)
  return fin_pred

# %%
res1 = make_preds(test_df)

# %%
int(res1[0])

# %%
print("Prediction is {}".format(int(res1[0])))

# %%
def download_nifty_data():
  close_list = []
  for i in range(1,83):
    i = str(i)
    n = dom.xpath('/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[2]/div/div/section/div[2]/table/tbody/tr['+i+']/td[6]/span')[0].text
    n = float(re.sub(",","",n))      # Removing commas from closing price and converting it as float datatype
    close_list.append(n)
  return close_list

# %%
def make_preds():
    last_data = []
    last_data = download_nifty_data()
    test_df = pd.DataFrame()
    test_df['Close'] = last_data
    scaler = MinMaxScaler(feature_range=(0, 1))
    test_df = test_df.iloc[::-1]  # inverting dataframe
    test_df = scaler.fit_transform(np.array(test_df).reshape(-1, 1))
    X, Y = create_time_data(test_df)  # Converting into X numpy array with 80 features and a Y numpy array.
    print(X.shape)
    X = X.reshape(X.shape[0], X.shape[1], 1)  # Reshaping array for LSTM model
    X = X[-1:]
    fin_pred = model.predict(X)
    fin_pred = scaler.inverse_transform(fin_pred)
    fin_pred = int(fin_pred[0])
    return render_template('index.html', prediction_text='Nifty prediction for tomorrow is: {}'.format(fin_pred))

# %%
# !pip install requests_html

# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
import requests
from lxml import etree
import re

# %%
url = 'https://finance.yahoo.com/quote/%5ENSEI/history/'

# %%
HEADERS = ({'User-Agent':
            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 \
            (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',\
            'Accept-Language': 'en-US, en;q=0.5'})

# %%
page = requests.get(url,headers=HEADERS, data={'ajax': True, 'mobile': False})

# %%
soup = BeautifulSoup(page.content,"html.parser")

# %%
dom = etree.HTML(str(soup))

# %%
df_tt = pd.DataFrame()

# %%
df_tt['Close'] = download_nifty_data()

# %%
df_tt

# %%
df_tt = df_tt.iloc[::-1]    # Inverting DataFrame

# %%
df_tt.reset_index(drop=True, inplace=True)

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(Y_train,train_predict))

# %%
math.sqrt(mean_squared_error(Y_test,test_predict))

# %%
# RMSE for 50-50-50 layered LSTM : 17317.295187511467

# %%
look_back=100
trainPredictPlot = np.empty_like(df_close)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(df_close)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df_close)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df_close))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Adding twitter sentiment as a feature to our dataset:

# %%
df.head()

# %%
df_tweets = pd.read_csv(r"C:\Users\rajku\OneDrive\Desktop\PBL 2\dftweets_sentiment.csv")

# %%
df_tweets

# %%
# df_tweets.dtypes

# %%
df_tweets = df_tweets.drop('Unnamed: 0',axis=1)

# %%
df_tweets["Date_dt"] = df_tweets["Date"].values.astype('datetime64[D]')

# %%
df_tweets["Day"] = df_tweets["Date_dt"].dt.day

# %%
df_tweets["weekday"] = df_tweets["Date_dt"].dt.weekday

# %%
df_tweets.head()

# %%
df

# %%
df_tweets_final

# %%
df

# %%
df_tweets

# %%
# function created for deleting tweets when stocks data isn't recorded (eg. sunday)
for i,row in df.iterrows():
  del_el = True
  for element in df_tweets['Date_dt']:
    if df["Date_dt"][i] == element:
      del_el = False
      break
  if del_el:
    print(i)

# %%
df_tweets[1820:1835]

# %%
df

# %%
import datetime

# %%
extra_date = datetime.datetime(2017, 8, 31)

# %%
row1 = ["2017-08-31",1,extra_date,31,3]

# %%
1827

# %%
df_tweets.loc[1826.5] = row1
df_tweets = df_tweets.sort_index().reset_index(drop = True)

# %%
# function created for deleting tweets when stocks data isn't recorded (eg. sunday)
for i,row in df_tweets.iterrows():
  del_el = True
  for element in df['Date_dt']:
    if df_tweets["Date_dt"][i] == element:
      del_el = False
      break
  if del_el:
    df_tweets.drop(i,axis=0,inplace=True)

# %%
df_tweets.reset_index(drop=True, inplace=True)

# %%
df_tweets

# %%
df

# %%
df_tweets = df_tweets.iloc[::-1]  # Inverting the dataframe

# %%
df_tweets.reset_index(drop=True, inplace=True)

# %%
df_tweets

# %%
df_final = pd.DataFrame(data=df["Close"])

# %%
df_final["Sentiment"] = df_tweets["Daily_sentiment"]

# %%
df_final

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler = scaler.fit(df_final)
df_final_scaled = scaler.transform(df_final)

# %%
df_final_scaled

# %%
train_size = int(len(df_final_scaled)*0.75)
test_size = int(len(df_final_scaled)*0.25)

# %%
df_train = df_final_scaled[0:train_size,:]
df_test = df_final_scaled[train_size:len(df_final_scaled),:]

# %%
X_train = []
Y_train = []

# %%
for i in range(100, train_size - 1 +1):
    X_train.append(df_train[i - 100:i, 0:df_final.shape[1]])
    Y_train.append(df_train[i + 1 - 1:i + 1, 0])

# %%
X_train,Y_train = np.array(X_train),np.array(Y_train)

# %%
X_test = []
Y_test = []

# %%
for i in range(100, test_size - 1 +1):
    X_test.append(df_test[i - 100:i, 0:df_final.shape[1]])
    Y_test.append(df_test[i + 1 - 1:i + 1, 0])

# %%
X_test,Y_test = np.array(X_test),np.array(Y_test)

# %%
X_test

# %%
model = Sequential()
model.add(LSTM(20, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(20,  return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(Y_train.shape[1]))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()

# %%
history = model.fit(X_train, Y_train, epochs=20, batch_size=64, validation_split=0.1, verbose=1)

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# %%
train_predict=model.predict(X_train)
#test_predict=model.predict(X_test)

# %%
test_predict=model.predict(X_test)

# %%
test_predict

# %%
test_copies = np.repeat(test_predict, df_test.shape[1], axis=-1)

# %%
test_copies=scaler.inverse_transform(test_copies)

# %%
prediction_copies = np.repeat(train_predict, df_train.shape[1], axis=-1) # adding a duplicate column for it to
# match the shape for inverse tranform

# %%
prediction_copies=scaler.inverse_transform(prediction_copies)

# %%
prediction_copies

# %%
prediction_copies = np.delete(prediction_copies, 1, 1)

# %%
prediction_copies

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(Y_train,prediction_copies))

# %%
df_final_scaled

# %%
test_copies

# %%
test_copies = np.delete(test_copies, 1, 1)

# %%
look_back=100
trainPredictPlot = np.empty_like(df_final_scaled)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(prediction_copies)+look_back, :] = prediction_copies

testPredictPlot = np.empty_like(df_final_scaled)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(prediction_copies)+(look_back*2)+1:len(df_final_scaled), :] = test_copies

plt.plot(df_final['Close'])
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from bs4 import BeautifulSoup
import requests
from lxml import etree
import re

app = Flask(__name__)
ngrok.set_auth_token("2JDNjznpCvz6dO2azRMYoBOtPSl_3zHP68shUQqtQNjBNNQvJ")
public_url =  ngrok.connect(port_no).public_url
url = 'https://finance.yahoo.com/quote/%5ENSEI/history/'
HEADERS = ({'User-Agent':
            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 \
            (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',\
            'Accept-Language': 'en-US, en;q=0.5'})

page = requests.get(url,headers=HEADERS, data={'ajax': True, 'mobile': False})
soup = BeautifulSoup(page.content,"html.parser")
dom = etree.HTML(str(soup))

model = pickle.load(open('model.pkl','rb'))

def download_nifty_data():
  close_list = []
  for i in range(1,83):
    i = str(i)
    n = dom.xpath('/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[2]/div/div/section/div[2]/table/tbody/tr['+i+']/td[6]/span')[0].text
    n = float(re.sub(",","",n))      # Removing commas from closing price and converting it as float datatype
    close_list.append(n)
  return close_list


def create_time_data(dataset):
    X = []
    Y = []
    for i in range(len(dataset)-101):
        a = dataset[i:(i+100),0]
        X.append(a)
        Y.append(dataset[i + 100,0])
    return np.array(X), np.array(Y)


def open_site():
    return render_template("index.html")


def make_preds():
    last_data = []
    last_data = download_nifty_data()
    test_df = pd.DataFrame()
    test_df['Close'] = last_data
    scaler = MinMaxScaler(feature_range=(0, 1))
    test_df = test_df.iloc[::-1]  # inverting dataframe
    test_df = scaler.fit_transform(np.array(test_df).reshape(-1, 1))
    X, Y = create_time_data(test_df)  # Converting into X numpy array with 100 features and a Y numpy array.
    print(X.shape)
    X = X.reshape(X.shape[0], X.shape[1], 1)  # Reshaping array for LSTM model
    X = X[-1:]
    fin_pred = model.predict(X)
    fin_pred = scaler.inverse_transform(fin_pred)
    fin_pred = int(fin_pred[0])
    return render_template('index.html', prediction_text='Nifty prediction for tomorrow is: {}'.format(fin_pred))
